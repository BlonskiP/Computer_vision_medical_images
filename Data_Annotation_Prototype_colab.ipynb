# %%
from PIL import Image
import numpy as np                         
from skimage import measure
from shapely.geometry import Polygon, MultiPolygon
import json
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/Machine learning/data.zip"
# !unzip "/content/drive/MyDrive/Machine learning/data.zip"
# Out:
# Archive:  /content/drive/MyDrive/Machine learning/data.zip
#    creating: data/lesion/
#    creating: data/lesion/P001/
#   inflating: data/lesion/P001/P001.10006.bmp
#   inflating: data/lesion/P001/P001.10007.bmp
#   inflating: data/lesion/P001/P001.10008.bmp
#   inflating: data/lesion/P001/P001.10009.bmp
#   inflating: data/lesion/P001/P001.10010.bmp
#   inflating: data/lesion/P001/P001.10011.bmp
#   inflating: data/lesion/P001/P001.10012.bmp
#   inflating: data/lesion/P001/P001.10013.bmp
#   inflating: data/lesion/P001/P001.10014.bmp
#   inflating: data/lesion/P001/P001.10015.bmp
#   inflating: data/lesion/P001/P001.10016.bmp
#   inflating: data/lesion/P001/P001.10017.bmp
#   inflating: data/lesion/P001/P001.10018.bmp
#   inflating: data/lesion/P001/P001.10019.bmp
#   inflating: data/lesion/P001/P001.10020.bmp
#   inflating: data/lesion/P001/P001.10021.bmp
#    creating: data/lesion/P002/
#   inflating: data/lesion/P002/P002.10006.bmp
#   inflating: data/lesion/P002/P002.10007.bmp
#   inflating: data/lesion/P002/P002.10008.bmp
#   inflating: data/lesion/P002/P002.10009.bmp
#   inflating: data/lesion/P002/P002.10010.bmp
#   inflating: data/lesion/P002/P002.10011.bmp
#   inflating: data/lesion/P002/P002.10012.bmp
#   inflating: data/lesion/P002/P002.10013.bmp
#   inflating: data/lesion/P002/P002.10014.bmp
#   inflating: data/lesion/P002/P002.10015.bmp
#   inflating: data/lesion/P002/P002.10016.bmp
#   inflating: data/lesion/P002/P002.10017.bmp
#   inflating: data/lesion/P002/P002.10018.bmp
#   inflating: data/lesion/P002/P002.10019.bmp
#   inflating: data/lesion/P002/P002.10020.bmp
#   inflating: data/lesion/P002/P002.10021.bmp
#   inflating: data/lesion/P002/P002.10022.bmp
#    creating: data/lesion/P003/
#   inflating: data/lesion/P003/P003.10007.bmp
#   inflating: data/lesion/P003/P003.10008.bmp
#   inflating: data/lesion/P003/P003.10009.bmp
#   inflating: data/lesion/P003/P003.10010.bmp
#   inflating: data/lesion/P003/P003.10011.bmp
#   inflating: data/lesion/P003/P003.10012.bmp
#   inflating: data/lesion/P003/P003.10013.bmp
#   inflating: data/lesion/P003/P003.10014.bmp
#   inflating: data/lesion/P003/P003.10015.bmp
#   inflating: data/lesion/P003/P003.10016.bmp
#   inflating: data/lesion/P003/P003.10017.bmp
#   inflating: data/lesion/P003/P003.10018.bmp
#   inflating: data/lesion/P003/P003.10019.bmp
#   inflating: data/lesion/P003/P003.10020.bmp
#   inflating: data/lesion/P003/P003.10021.bmp
#    creating: data/lesion/P004/
#   inflating: data/lesion/P004/P004.10008.bmp
#   inflating: data/lesion/P004/P004.10009.bmp
#   inflating: data/lesion/P004/P004.10010.bmp
#   inflating: data/lesion/P055/P055.10013.bmp
#   inflating: data/lesion/P055/P055.10014.bmp
#   inflating: data/lesion/P055/P055.10015.bmp
#   inflating: data/lesion/P055/P055.10016.bmp
#   inflating: data/lesion/P055/P055.10017.bmp
#   inflating: data/lesion/P055/P055.10018.bmp
#    creating: data/lesion/P056/
#    creating: data/lesion/P058/
#   inflating: data/lesion/P058/P058.10005.bmp
#   inflating: data/lesion/P058/P058.10006.bmp
#   inflating: data/lesion/P058/P058.10007.bmp
#   inflating: data/lesion/P058/P058.10008.bmp
#   inflating: data/lesion/P058/P058.10009.bmp
#   inflating: data/lesion/P058/P058.10010.bmp
#   inflating: data/lesion/P058/P058.10011.bmp
#   inflating: data/lesion/P058/P058.10012.bmp
#   inflating: data/lesion/P058/P058.10013.bmp
#   inflating: data/lesion/P058/P058.10014.bmp
#   inflating: data/lesion/P058/P058.10015.bmp
#   inflating: data/lesion/P058/P058.10016.bmp
#   inflating: data/lesion/P058/P058.10017.bmp
#   inflating: data/lesion/P058/P058.10018.bmp
#    creating: data/lesion/P059/
#    creating: data/lesion/P060/
#    creating: data/lesion/P061/
#    creating: data/lesion/P062/
#    creating: data/lesion/P063/
#    creating: data/lesion/P064/
#   inflating: data/lesion/P064/P064.10006.bmp
#   inflating: data/lesion/P064/P064.10007.bmp
#   inflating: data/lesion/P064/P064.10008.bmp
#   inflating: data/lesion/P064/P064.10009.bmp
#   inflating: data/lesion/P064/P064.10010.bmp
#   inflating: data/lesion/P064/P064.10011.bmp
#   inflating: data/lesion/P064/P064.10012.bmp
#   inflating: data/lesion/P064/P064.10013.bmp
#   inflating: data/lesion/P064/P064.10014.bmp
#   inflating: data/lesion/P064/P064.10015.bmp
#   inflating: data/lesion/P064/P064.10016.bmp
#   inflating: data/lesion/P064/P064.10017.bmp
#    creating: data/lesion/P065/
#    creating: data/lesion/P066/
#    creating: data/lesion/P067/
#    creating: data/lesion/P068/

# %%
def create_sub_masks(mask_image):
    width, height = mask_image.size

    # Initialize a dictionary of sub-masks indexed by RGB colors
    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x,y))[:3]

            # If the pixel is not white...(we have white background)
            if pixel != (255, 255, 255):
                # Check to see if we've created a sub-mask...
                pixel_str = str(pixel)
                sub_mask = sub_masks.get(pixel_str)
                if sub_mask is None:
                   # Create a sub-mask (one bit per pixel) and add to the dictionary
                    # Note: we add 1 pixel of padding in each direction
                    # because the contours module doesn't handle cases
                    # where pixels bleed to the edge of the image
                    sub_masks[pixel_str] = Image.new('1', (width+2, height+2))

                # Set the pixel value to 1 (default is 0), accounting for padding
                sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks

# %%
def create_sub_mask_annotation(sub_mask, image_id, category_id, annotation_id, is_crowd):
    #     measure.find_contours
    #Uses the “marching squares” method to compute a the iso-valued contours of 
    #the input 2D array for a particular level value. 
    contours = measure.find_contours(sub_mask, 0.5, positive_orientation='low')
    bboxes = []
    segmentations = []
    polygons = []
    areas = []
    annotations = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        #shapely.geometry Polygon
        
        poly = Polygon(contour)
        poly = poly.simplify(1.0, preserve_topology=False)
        segmentation = np.array(poly.exterior.coords).ravel().tolist()
        if len(segmentation)>1:
          segmentations.append([segmentation])
          polygons.append(poly)
    # Combine the polygons to calculate the bounding box and area
    offset = 0
    steps = 0
    for i , polygon in enumerate(polygons):
        bbox = []
        area = []
        if not polygon.is_empty:
            bbox = polygon.bounds
            area = polygon.area
        annotation = {
        'segmentation': segmentations[i],
        'iscrowd': 0,
        'image_id': image_id,
        'category_id': category_id,
        'id': annotation_id,
        'bbox': bbox,
        'area': area}
        annotations.append(annotation)
        steps +=1
        annotation_id += 1
    return annotations

# %%
errors=['./data/lesion/P009/10014.bmp',
 './data/lesion/P006/10011.bmp',
 './data/lesion/P058/10006.bmp',
 './data/lesion/P058/10016.bmp',
 './data/lesion/P032/10013.bmp',
 './data/lesion/P028/10007.bmp',
 './data/lesion/P013/10011.bmp',
 './data/lesion/P016/10012.bmp',
 './data/lesion/P016/10018.bmp']

# %%
coco_annotations={
    'info':{
        'description':'Dataset of brain lesions',
        'url':"",
        'year':2020,
        "contributor":"Dr. Martin Tabakow",
        "date_created": ""
    }, 
    'licenses':{
        'url':"",
        "id":0,
        'name':""
    },
    'images':[],
    'annotations':[],
    'categories':[]
}

# %%
coco_annotations['categories'].append({
    'supercategory':'brain damage',
    'id':1,
    'name':'cortical lesion'
})
coco_annotations['categories'].append({
    'supercategory':'brain damage',
    'id':2,
    'name':'subcortical lesion'
})

# %%
import os
from tqdm import tqdm
data_path = "./data/"
out_path = "/content/drive/MyDrive/Machine learning/brain_annotations.json"

with open(out_path,'w') as json_file:            
    json.dump(coco_annotations,json_file)

lesion_id = 1
is_crowd= 0
image_id = 1
annotation_id = 1
for (root,dirs,files) in os.walk(data_path, topdown=True):
    for filename in files:
        if filename.endswith('.bmp'):
          path = os.path.join(root, filename)
          if path not in errors:
            image={
            'license':0,
            'file_name':filename,
            'width':512,
            'height':512,
            'id':image_id
            }
            with Image.open(path) as mask_image:
              sub_masks = create_sub_masks(mask_image)
              for color, sub_mask in sub_masks.items():
                category_id = lesion_id
                annotations = create_sub_mask_annotation(sub_mask, image_id, category_id,annotation_id, is_crowd)
                annotation_id += len(annotations)
                for annotation in annotations:
                  with open(out_path,'r') as outfile:
                    data=json.load(outfile)
                    data['annotations'].append(annotation)
                  with open(out_path, "w") as outfile:
                    json.dump(data,outfile)
              with open(out_path,'r') as outfile:
                    data=json.load(outfile)
                    data['images'].append(image)
              with open(out_path, "w") as outfile:
                    json.dump(data,outfile)
              image_id+=1
